# %% [markdown]
# NAME :
#
# Please follow along in class, add code cells as we go please

# %%
import csv

def write_sample_books_csv(filename: str = "books.csv") -> None:
    """
    Writes a small, classroom-friendly books dataset to a CSV file.

    Creates/overwrites `filename`.
    """
    header = ["title", "author", "year", "country", "genre"]
    rows = [
        ["Little Women", "Louisa May Alcott", 1868, "United States", "Classic"],
        ["Anne of Green Gables", "L. M. Montgomery", 1908, "Canada", "Classic"],
        ["Heidi", "Johanna Spyri", 1881, "Switzerland", "Classic"],
        ["A Little Princess", "Frances Hodgson Burnett", 1905, "England", "Classic"],
        ["The Secret Garden", "Frances Hodgson Burnett", 1911, "England", "Classic"],
        ["Pollyanna", "Eleanor H. Porter", 1913, "United States", "Classic"],
        ["Black Beauty", "Anna Sewell", 1877, "England", "Classic"],
        ["Rebecca of Sunnybrook Farm", "Kate Douglas Wiggin", 1903, "United States", "Classic"],
        ["Eight Cousins", "Louisa May Alcott", 1875, "United States", "Classic"],
        ["What Katy Did", "Susan Coolidge", 1872, "United States", "Classic"],
    ]

    # newline="" is important on Windows/Colab to avoid blank lines in CSV output
    with open(filename, "w", encoding="utf-8", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(header)
        writer.writerows(rows)


# Example usage in Colab:
# 1) Write the file
write_sample_books_csv("books.csv")

# %% [markdown]
# ## 1) Exercise
# See if you can write a function that does the same thing as the shell command !head. It should take as arguments the name of a file to read, the number of lines to read, and the name of the file to write the lines into. If the third parameter is None, it should display the lines rather than write them to a file.
#
# 1) head() without with or try

# %% [markdown]
# ### 2) Exercise
#
# "Wordle" is an online word game where the objective is to guess a five-letter word in six or fewer attempts.
# Each attempt has to be recognized as a word, not including proper nouns.
# After each attempt, you get information about which of the letters you guessed appear in the target word, and which ones are in the correct position.
#
# For example, suppose the target word is `MOWER` and you guess `TRIED`.
# You would learn that `E` is in the word and in the correct position, `R` is in the word but not in the correct position, and `T`, `I`, and `D` are not in the word.
#
# As a different example, suppose you have guessed the words `SPADE` and `CLERK`, and you've learned that `E` is in the word, but not in either of those positions, and none of the other letters appear in the word.
# Of the words in the word list, how many could be the target word?
# Write a function called `check_word` that takes a five-letter word and checks whether it could be the target word, given these guesses.
#
# 2) Wordle filter after guesses SPADE and CLERK
#
# Given:
#
# Only E is in the target word
#
# E is not in position 4 (from SPADE) and not in position 2 (from CLERK)
#
# Letters S P A D C L R K are not in the word at all
#
# Also: in Wordle, letters are unique? (Not necessarily.) We will not assume uniqueness.
#
# So a valid target word must:
#
# contain 'e'
#
# have word[1] != 'e' and word[4] != 'e'
#
# contain none of the forbidden letters besides possibly 'e' (but 'e' is not forbidden)

# %% [markdown]
# ### 3) Add the new guess TOTEM: E still wrong place, M is correct
#
# Interpretation consistent with the previous problem:
#
# From TOTEM, you learn:
#
# M is in the correct position. In TOTEM, M is last → index 4.
#
# E is still not in the right place. In TOTEM, E is index 3, so E is not at index 3.
#
# The prior constraints still hold:
#
# E not at index 2 or 4
#
# No letters from spadclrk appear
#
# Also from TOTEM: letters T, O are not in the word (and the first M at index 2 is not correct, so it suggests M is not at index 2; we can include that too if you want stricter Wordle logic)
#
# Here’s a clean “continuation” version:

# %%
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt');

# %% [markdown]
# ### 4) Count lines containing pale/pales/paled/paleness/pallor — no regex version
#
# You asked for regex in the prompt, but you also told me for class you want classic strings and no regex. Here’s a strong string-based solution that also avoids matching impale.
#
# Approach:
#
# lowercase each line
#
# split into “words” by turning punctuation into spaces
#
# then check whether any cleaned word starts with pale (pale/pales/paled/paleness) OR equals pallor

# %%
def write_pg345_cleaned(filename: str = "pg345_cleaned.txt") -> None:
    """
    Writes a small, cleaned text file suitable for string-processing exercises.
    Intended for use in Google Colab.
    """
    text = [
        "The young man grew pale as the truth was revealed to him.",
        "His face paled further when he heard the accusation spoken aloud.",
        "A sudden pallor spread across her features, betraying her fear.",
        "He stood silent, pale and unmoving, as though turned to stone.",
        "There was a strange paleness about him that could not be ignored.",
        "",
        "The room was quiet, lit only by a single candle.",
        "No one spoke, and the air itself seemed to tremble.",
        "She tried to steady her voice, but her pallor remained.",
        "He did not impale his enemy with words, but the silence cut deeper.",
        "",
        "At last, the moment passed, and color slowly returned to his face."
    ]

    fout = open(filename, "w", encoding="utf-8")
    for line in text:
        fout.write(line + "\n")
    fout.close()

# %%
write_pg345_cleaned()
print(count_pale_lines("pg345_cleaned.txt"))

# %% [markdown]
# ### FROM HOMEWORK MOD 10
# ## 1. Classifying Strings
# Write a function that describes what kind of characters a string contains using the methods:
#
# - `s.isalpha()`
# - `s.isdigit()`
# - `s.isspace()`
#
# Your function should return a short message describing the string. You may include other checks if you wish (for example, checking for a mix of types).

# %%
# TODO: Implement describe_string(s)
def describe_string(s: str) -> str:
    """Return a short description of what kinds of characters s contains.

    Examples of descriptions you might return (you may adjust wording):
    - 'all letters'
    - 'all digits'
    - 'only whitespace'
    - 'mixed characters'
    """
    # Hint: use isalpha(), isdigit(), and isspace().
    # Add your logic here.
    pass

# TODO: Test your function with at least 5 different strings.
# Example test cases (you think about expected results):
# print(describe_string("Hello"))
# print(describe_string("12345"))
# print(describe_string("   "))
# print(describe_string("Hello123"))
# print(describe_string("Hi there"))

# %% [markdown]
# ✅ 2. normalize_name(raw_name)

# %% [markdown]
# ## 2. Normalizing Names
# Suppose you receive names from a form with messy spacing and casing.
# Write a function `normalize_name(raw_name)` that:
#
# 1. Strips leading and trailing whitespace.
# 2. Converts the name to **title case** (first letter of each word capitalized).
#
# Use string methods such as `strip()`, `lower()`, `upper()`, `capitalize()`, or `title()`.

# %%
# TODO: Implement normalize_name(raw_name)
def normalize_name(raw_name: str) -> str:
    """Return a cleaned, nicely formatted version of raw_name.

    Steps:
    1. Remove extra spaces at the start and end.
    2. Ensure each word begins with an uppercase letter.
    """
    # Implement using string methods.
    pass

# TODO: Test your function with several inputs.
# Example ideas:
# '   cHaNa   '
# '  toURO college  '
# 'mcon 141'
# print(normalize_name("   cHaNa   "))

# %% [markdown]
# ## 3. Counting Vowels
# Write a function `count_vowels(s)` that returns the number of vowels in a string.
#
# Requirements:
# - Treat both uppercase and lowercase vowels the same (A, E, I, O, U).
# - You may use a `for` loop over the string.
# - You can store the vowels in a string like `vowels = "aeiou"`.
#
# Do **not** use any external libraries.

# %%
# TODO: Implement count_vowels(s)
def count_vowels(s: str) -> int:
    """Return the number of vowels in s.

    Treat uppercase and lowercase vowels as the same.
    """
    # Hint: consider converting to lower() first.
    # Then count how many characters are in a set/string of vowels.
    pass

# TODO: Test your function.
# print(count_vowels("Touro LAS"))
# print(count_vowels("HELLO"))
# print(count_vowels("bcd"))

# %% [markdown]
# ## 4. Simple Censor with `replace()`
# Write a function `censor_word(text, bad_word)` that replaces every occurrence of `bad_word` in `text` with a censored version made of asterisks.
#
# For example (your actual tests can vary):
# - `censor_word("I love cake", "cake")` → `"I love ****"`
#
# Use the `replace(old, new)` string method.

# %%
# TODO: Implement censor_word(text, bad_word)
def censor_word(text: str, bad_word: str) -> str:
    """Return a new string where every occurrence of bad_word
    in text is replaced by asterisks of the same length.
    """
    # Hint: build the censored version using '*' * len(bad_word)
    # Then use replace().
    pass

# TODO: Test your function with multiple examples.
# print(censor_word("I love cake", "cake"))

# %% [markdown]
# 4. censor_word(text, bad_word)
# def censor_word(text: str, bad_word: str) -> str:
#     stars = "*" * len(bad_word)
#     return text.replace(bad_word, stars)
#
#
# Example:
#
# print(censor_word("I love cake", "cake"))

# %% [markdown]
# ## 5. Parsing Simple CSV-like Data
# Given a string representing a simple data line:
#
# ```python
# line = "Chana,19,MCON 141,New York"
# ```
#
# Write a function `parse_student(line)` that:
#
# 1. Uses `split(',')` to break the line into pieces.
# 2. Returns a list with all components of line

# %%
# TODO: Implement parse_student(line)
def parse_student(line: str) -> list:
    """Parse a CSV-like student line into a list.

    Example input: "Chana,19,MCON 141,New York"
    Example output :
        [
            'Chana',
            '19',
            'MCON 141',
            'New York'
        ]
    """
    # Hint: use split(',')

# TODO: Test your function.
# student = parse_student("Chana,19,MCON 141,New York")
# print(student)

# %% [markdown]
# ## 6. Building a Report Line with F-Strings
# Use f-strings to build a nicely formatted report line for a student.
#
# Write a function `format_student_report(name, score, max_score)` that returns a string like:
#
# ```
# Chana:  85/100 (85.0%)
# ```
#
# Requirements:
# - Use an f-string.
# - Right-align the numeric score in a small field (e.g. width 3 or 4).
# - Show the percentage with **one digit after the decimal point**.
#
# Do **not** print inside the function; just return the string.

# %%
# TODO: Implement format_student_report(name, score, max_score)
def format_student_report(name: str, score: int, max_score: int) -> str:
    """Return a formatted report line using an f-string.

    Example format (your spacing can vary):
        "Chana:  85/100 (85.0%)"
    """
    # Hint: percentage = score / max_score * 100
    # Use f-string formatting for width and for '.1f'.
    pass

# TODO: Test your function.
# print(format_student_report("Chana", 85, 100))

# %% [markdown]
# ## 7.  Custom `contains_digit`
# Write a function `contains_digit(s)` that returns True if the string `s` contains **at least one digit**, and False otherwise.
#
# **Rules:**
# - Do **not** use `any()` or list comprehensions
# - You may use `str.isdigit()` for each character.
# - Use a `for` loop and return as soon as you know the answer.

# %%
# TODO (Optional): Implement contains_digit(s)
def contains_digit(s: str) -> bool:
    """Return True if s contains at least one digit, else False.
    """
    # Hint: loop over each character and use .isdigit().
    pass

# TODO: Test your function with a few examples.
# print(contains_digit("abc"))
# print(contains_digit("abc3"))
# print(contains_digit("2025"))

# %% [markdown]
# ### String Q1 — Normalize a Name (Title Case, Clean Spaces)
#
# Write a function `normalize_name(name)` that:
#
# - strips leading/trailing whitespace
# - collapses **multiple spaces** inside the name to a single space
# - title-cases each part (e.g., `"  mARy   aNN  sMith "` → `"Mary Ann Smith"`)

# %% [markdown]
# String Q2 — Find All Occurrences (No Regex)
# Write a function find_all(haystack, needle) that returns a list of all start indices where needle occurs inside haystack, including overlaps.
#
# Example:
#
# find_all("aaaa", "aa") → [0, 1, 2] #notice that aa can be found 3 times within this haystack or string
# Hints:
#
# Use a loop and str.find(needle, start)
# Or use slicing checks

# %% [markdown]
# String Q3 — Run-Length Encode (RLE)
# Write a function rle_encode(s) that compresses a string by grouping consecutive runs.
#
# Rules:
#
# For each run, output the character followed by the run length.
# Example: "aaabbc" → "a3b2c1"
# Empty string → empty string
# No regex.

# %% [markdown]
# ### String Q4 — Safe Email Username
#
# Write a function `email_username(email)` that returns a "safe" username based on an email.
#
# Rules:
# - Take the part **before** the `@`
# - Convert to lowercase
# - Replace any spaces with `_`
# - Remove any characters that are not letters, digits, `_`, or `.`
#
# Assume input has exactly one `@`.

# %% [markdown]
# ### String Q5 — Pretty Column Formatter
#
# Write a function `format_columns(rows)` where `rows` is a list of strings like:
#
# `"apple,3"` or `"banana,12"`
#
# Return a **single formatted string** where:
# - Column 1 is left-aligned
# - Column 2 is right-aligned
# - Columns are separated by `" | "`
# - Use the width of the longest item name for column 1
# - Use the width of the longest number for column 2
#
# Example output:
# ```
# apple  |  3
# banana | 12
# ```
